# %% [markdown]
# # **교통 데이터: 지리 데이터 시각화**

# %% [markdown]
# ## **데이터 살펴보기**

# %% [markdown]
# [서울 열린데이터 광장](http://data.seoul.go.kr/dataList/OA-12252/S/1/datasetView.do)

# %%
import pandas as pd
import plotly.express as px

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('Data\서울시 지하철 호선별 역별 시간대별 승하차 인원 정보.csv')

# %%
data.head()
# Out:
#       사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  05시-06시 하차인원  \
# 0  202307  1호선  동대문           710            31         11581          2095
# 1  202307  1호선  동묘앞           221             2          3012          1090
# 2  202307  1호선  서울역           577            37          8434          9396
# 3  202307  1호선   시청            49             5          2381          4825
# 4  202307  1호선  신설동           392            35          8967          2356
#
#    06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  23시-24시 하차인원  00시-01시 승차인원  \
# 0          9027          6829         14177  ...          8930           511
# 1          3682          5042          7336  ...          4195           104
# 2         13088         51243         40143  ...         13987          2297
# 3          3784         22736          7558  ...          4285           287
# 4          9520          8509         21822  ...          9505           317
#
#    00시-01시 하차인원  01시-02시 승차인원  01시-02시 하차인원  02시-03시 승차인원  02시-03시 하차인원  \
# 0          2412             0           216             0             0
# 1          1649             0           272             0             0
# 2          2598             1           219             0             0
# 3          1085             0            12             0             0
# 4          2244             0             0             0             0
#
#    03시-04시 승차인원  03시-04시 하차인원      작업일자
# 0             0             0  20230803
# 1             0             0  20230803
# 2             0             0  20230803
# 3             0             0  20230803
# 4             0             0  20230803
#
# [5 rows x 52 columns]

# %% [markdown]
# - 서울시 지하철 승하차인원의 월별 합계

# %% [markdown]
# - 2018년 이후, 2호선만, 승차 인원만 분석 예정

# %% [markdown]
# ## **질문 만들기**

# %% [markdown]
# - 승차 인원이 가장 많은 역은?
# - 연도별로 혹은 월별로 승차 인원 추이에 차이가 있는가?
# - 시간대별로 가장 승차인원이 많은 역은?
# - 지하철역 시간대별 인원 유형 군집화
# - 지도에 분석 결과를 시각화하기

# %% [markdown]
# ## **데이터 전처리**

# %% [markdown]
# - 날짜 컬럼 추가

# %%
data['연도'] = pd.to_datetime(data['사용월'], format='%Y%m').dt.year
data['월'] = pd.to_datetime(data['사용월'], format='%Y%m').dt.month

data.head()
# Out:
#       사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  05시-06시 하차인원  \
# 0  202307  1호선  동대문           710            31         11581          2095
# 1  202307  1호선  동묘앞           221             2          3012          1090
# 2  202307  1호선  서울역           577            37          8434          9396
# 3  202307  1호선   시청            49             5          2381          4825
# 4  202307  1호선  신설동           392            35          8967          2356
#
#    06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  00시-01시 하차인원  01시-02시 승차인원  \
# 0          9027          6829         14177  ...          2412             0
# 1          3682          5042          7336  ...          1649             0
# 2         13088         51243         40143  ...          2598             1
# 3          3784         22736          7558  ...          1085             0
# 4          9520          8509         21822  ...          2244             0
#
#    01시-02시 하차인원  02시-03시 승차인원  02시-03시 하차인원  03시-04시 승차인원  03시-04시 하차인원  \
# 0           216             0             0             0             0
# 1           272             0             0             0             0
# 2           219             0             0             0             0
# 3            12             0             0             0             0
# 4             0             0             0             0             0
#
#        작업일자    연도  월
# 0  20230803  2023  7
# 1  20230803  2023  7
# 2  20230803  2023  7
# 3  20230803  2023  7
# 4  20230803  2023  7
#
# [5 rows x 54 columns]

# %% [markdown]
# - 2018년 이후, 2호선만 필터링

# %%
data = data.query('호선명 == "2호선" and 연도 >= 2018')

# %% [markdown]
# - 지하철역명 통일

# %%
sorted(data['지하철역'].unique())
# Out:
# ['강남',
#  '강변(동서울터미널)',
#  '건대입구',
#  '교대(법원.검찰청)',
#  '구로디지털단지',
#  '구의(광진구청)',
#  '낙성대',
#  '낙성대(강감찬)',
#  '당산',
#  '대림(구로구청)',
#  '도림천',
#  '동대문역사문화공원',
#  '동대문역사문화공원(DDP)',
#  '뚝섬',
#  '문래',
#  '방배',
#  '봉천',
#  '사당',
#  '삼성(무역센터)',
#  '상왕십리',
#  '서울대입구(관악구청)',
#  '서초',
#  '선릉',
#  '성수',
#  '시청',
#  '신답',
#  '신당',
#  '신대방',
#  '신도림',
#  '신림',
#  '신설동',
#  '신정네거리',
#  '신촌',
#  '아현',
#  '양천구청',
#  '역삼',
#  '영등포구청',
#  '왕십리(성동구청)',
#  '용답',
#  '용두(동대문구청)',
#  '을지로3가',
#  '을지로4가',
#  '을지로입구',
#  '이대',
#  '잠실(송파구청)',
#  '잠실나루',
#  '잠실새내',
#  '종합운동장',
#  '충정로(경기대입구)',
#  '한양대',
#  '합정',
#  '홍대입구']

# %%
data['지하철역'] = [i[0] for i in data['지하철역'].str.split('(')]
sorted(data['지하철역'].unique())
# Out:
# ['강남',
#  '강변',
#  '건대입구',
#  '교대',
#  '구로디지털단지',
#  '구의',
#  '낙성대',
#  '당산',
#  '대림',
#  '도림천',
#  '동대문역사문화공원',
#  '뚝섬',
#  '문래',
#  '방배',
#  '봉천',
#  '사당',
#  '삼성',
#  '상왕십리',
#  '서울대입구',
#  '서초',
#  '선릉',
#  '성수',
#  '시청',
#  '신답',
#  '신당',
#  '신대방',
#  '신도림',
#  '신림',
#  '신설동',
#  '신정네거리',
#  '신촌',
#  '아현',
#  '양천구청',
#  '역삼',
#  '영등포구청',
#  '왕십리',
#  '용답',
#  '용두',
#  '을지로3가',
#  '을지로4가',
#  '을지로입구',
#  '이대',
#  '잠실',
#  '잠실나루',
#  '잠실새내',
#  '종합운동장',
#  '충정로',
#  '한양대',
#  '합정',
#  '홍대입구']

# %% [markdown]
# - 승차 인원만 추출하기

# %%
on_col = [i for i in data.columns if '승차' in i]
data = data[['사용월','연도','월','지하철역']+on_col]

data.head()
# Out:
#        사용월    연도  월     지하철역  04시-05시 승차인원  05시-06시 승차인원  06시-07시 승차인원  \
# 10  202307  2023  7       강남           120          9359         18503
# 11  202307  2023  7       강변            27          8936         28877
# 12  202307  2023  7     건대입구           290         16965         22074
# 13  202307  2023  7       교대            15          2693         11535
# 14  202307  2023  7  구로디지털단지           369         38505         53882
#
#     07시-08시 승차인원  08시-09시 승차인원  09시-10시 승차인원  ...  18시-19시 승차인원  19시-20시 승차인원  \
# 10         40112         64256         52713  ...        327480        215011
# 11         78164        117728         82763  ...         61291         43557
# 12         53127         91248         61438  ...         85337         64419
# 13         25250         36820         27461  ...        133358         62654
# 14        144838        184498        112257  ...        210532        101581
#
#     20시-21시 승차인원  21시-22시 승차인원  22시-23시 승차인원  23시-24시 승차인원  00시-01시 승차인원  \
# 10        172551        196756        177694         80992         13773
# 11         32792         27539         19267          7874          1058
# 12         65838         72636         74202         45555          7559
# 13         51239         53658         42819         15754          3171
# 14         65184         55202         41572         18845          3463
#
#     01시-02시 승차인원  02시-03시 승차인원  03시-04시 승차인원
# 10             3             0             0
# 11             1             0             0
# 12             3             0             0
# 13             2             0             0
# 14             6             0             0
#
# [5 rows x 28 columns]

# %% [markdown]
# ## **분석**

# %% [markdown]
# ### [1] 승차 인원이 가장 많은 역은?

# %% [markdown]
# - 합계 컬럼 만들기

# %%
data['합계'] = data[on_col].sum(axis=1)

data.head()
# Out:
#        사용월    연도  월     지하철역  04시-05시 승차인원  05시-06시 승차인원  06시-07시 승차인원  \
# 10  202307  2023  7       강남           120          9359         18503
# 11  202307  2023  7       강변            27          8936         28877
# 12  202307  2023  7     건대입구           290         16965         22074
# 13  202307  2023  7       교대            15          2693         11535
# 14  202307  2023  7  구로디지털단지           369         38505         53882
#
#     07시-08시 승차인원  08시-09시 승차인원  09시-10시 승차인원  ...  19시-20시 승차인원  20시-21시 승차인원  \
# 10         40112         64256         52713  ...        215011        172551
# 11         78164        117728         82763  ...         43557         32792
# 12         53127         91248         61438  ...         64419         65838
# 13         25250         36820         27461  ...         62654         51239
# 14        144838        184498        112257  ...        101581         65184
#
#     21시-22시 승차인원  22시-23시 승차인원  23시-24시 승차인원  00시-01시 승차인원  01시-02시 승차인원  \
# 10        196756        177694         80992         13773             3
# 11         27539         19267          7874          1058             1
# 12         72636         74202         45555          7559             3
# 13         53658         42819         15754          3171             2
# 14         55202         41572         18845          3463             6
#
#     02시-03시 승차인원  03시-04시 승차인원       합계
# 10             0             0  2408376
# 11             0             0   933338
# 12             0             0  1060476
# 13             0             0   852909
# 14             0             0  1629379
#
# [5 rows x 29 columns]

# %% [markdown]
# - 지하철역별 월평균 승차 인원 구하기

# %%
data_mean = data.groupby('지하철역')[['합계']].mean().reset_index().rename({'합계':'월평균'}, axis=1).sort_values('월평균', ascending=False)
data_mean
# Out:
#          지하철역           월평균
# 0          강남  2.475218e+06
# 42         잠실  2.185502e+06
# 49       홍대입구  1.895644e+06
# 27         신림  1.815902e+06
# 4     구로디지털단지  1.656332e+06
# 16         삼성  1.496685e+06
# 26        신도림  1.481450e+06
# 20         선릉  1.463946e+06
# 18      서울대입구  1.390678e+06
# 33         역삼  1.286969e+06
# 40      을지로입구  1.210664e+06
# 30         신촌  1.120330e+06
# 15         사당  1.106371e+06
# 2        건대입구  1.101436e+06
# 1          강변  1.051275e+06
# 3          교대  9.273203e+05
# 48         합정  9.013917e+05
# 21         성수  8.819518e+05
# 6         낙성대  7.973586e+05
# 25        신대방  7.613010e+05
# 8          대림  7.384466e+05
# 14         봉천  6.745126e+05
# 5          구의  6.574240e+05
# 22         시청  6.447752e+05
# 44       잠실새내  6.408299e+05
# 19         서초  6.041791e+05
# 38      을지로3가  5.987181e+05
# 34      영등포구청  5.979428e+05
# 12         문래  5.598968e+05
# 11         뚝섬  5.533346e+05
# 7          당산  5.469038e+05
# 13         방배  4.974575e+05
# 35        왕십리  4.923307e+05
# 41         이대  4.486210e+05
# 10  동대문역사문화공원  4.202662e+05
# 43       잠실나루  4.144133e+05
# 24         신당  4.025609e+05
# 17       상왕십리  3.917267e+05
# 39      을지로4가  3.458677e+05
# 45      종합운동장  3.166940e+05
# 31         아현  2.913534e+05
# 46        충정로  2.824122e+05
# 29      신정네거리  2.765867e+05
# 47        한양대  2.678286e+05
# 32       양천구청  1.898572e+05
# 28        신설동  1.093200e+05
# 36         용답  7.761172e+04
# 37         용두  6.579101e+04
# 23         신답  4.381854e+04
# 9         도림천  3.452230e+04

# %%
fig = px.bar(data_frame = data_mean, x='지하철역', y='월평균', title='지하철역별 월평균 승차인원')
fig.show()

# %% [markdown]
# ### [2] 연도별로 혹은 월별로 승차 인원 추이에 차이가 있는가?

# %%
data.head()
# Out:
#        사용월    연도  월     지하철역  04시-05시 승차인원  05시-06시 승차인원  06시-07시 승차인원  \
# 10  202307  2023  7       강남           120          9359         18503
# 11  202307  2023  7       강변            27          8936         28877
# 12  202307  2023  7     건대입구           290         16965         22074
# 13  202307  2023  7       교대            15          2693         11535
# 14  202307  2023  7  구로디지털단지           369         38505         53882
#
#     07시-08시 승차인원  08시-09시 승차인원  09시-10시 승차인원  ...  19시-20시 승차인원  20시-21시 승차인원  \
# 10         40112         64256         52713  ...        215011        172551
# 11         78164        117728         82763  ...         43557         32792
# 12         53127         91248         61438  ...         64419         65838
# 13         25250         36820         27461  ...         62654         51239
# 14        144838        184498        112257  ...        101581         65184
#
#     21시-22시 승차인원  22시-23시 승차인원  23시-24시 승차인원  00시-01시 승차인원  01시-02시 승차인원  \
# 10        196756        177694         80992         13773             3
# 11         27539         19267          7874          1058             1
# 12         72636         74202         45555          7559             3
# 13         53658         42819         15754          3171             2
# 14         55202         41572         18845          3463             6
#
#     02시-03시 승차인원  03시-04시 승차인원       합계
# 10             0             0  2408376
# 11             0             0   933338
# 12             0             0  1060476
# 13             0             0   852909
# 14             0             0  1629379
#
# [5 rows x 29 columns]

# %%
year_sum = data.query('연도 <= 2022').groupby(['연도'])[['합계']].sum().reset_index()
year_sum['연도'] = year_sum['연도'].astype(str)

fig = px.line(data_frame=year_sum, x='연도', y='합계')
fig.show()

# %%
month_sum = data.query('연도 <= 2022').groupby(['월'])[['합계']].sum().reset_index()
month_sum['월'] = month_sum['월'].astype(str)

fig = px.line(data_frame=month_sum, x='월', y='합계')
fig.show()

# %% [markdown]
# ### [3] 시간대별로 가장 승차인원이 많은 역은?

# %%
top10 = data_mean.sort_values('월평균', ascending=False).head(10)['지하철역']
top10
# Out:
# 0          강남
# 42         잠실
# 49       홍대입구
# 27         신림
# 4     구로디지털단지
# 16         삼성
# 26        신도림
# 20         선릉
# 18      서울대입구
# 33         역삼
# Name: 지하철역, dtype: object

# %%
#주요 역 10개만 필터링하여 시간당 월평균 인원수 구하기
top10 = data_mean.sort_values('월평균', ascending=False).head(10)['지하철역']
top10_mean_hour = data.query('지하철역 in @top10').groupby('지하철역')[on_col].mean()
top10_mean_hour.columns = [i[:3] for i in top10_mean_hour.columns]

# %%
#전체 기준 히트맵
top10_mean_hour.style.background_gradient(cmap='pink_r', axis=None).format('{:.0f}')
# Out:
# <style  type="text/css" >
# #T_00b8e_row0_col0,#T_00b8e_row0_col21,#T_00b8e_row0_col22,#T_00b8e_row0_col23,#T_00b8e_row1_col0,#T_00b8e_row1_col21,#T_00b8e_row1_col22,#T_00b8e_row1_col23,#T_00b8e_row2_col0,#T_00b8e_row2_col21,#T_00b8e_row2_col22,#T_00b8e_row2_col23,#T_00b8e_row3_col21,#T_00b8e_row3_col22,#T_00b8e_row3_col23,#T_00b8e_row4_col0,#T_00b8e_row4_col21,#T_00b8e_row4_col22,#T_00b8e_row4_col23,#T_00b8e_row5_col21,#T_00b8e_row5_col22,#T_00b8e_row5_col23,#T_00b8e_row6_col0,#T_00b8e_row6_col21,#T_00b8e_row6_col22,#T_00b8e_row6_col23,#T_00b8e_row7_col0,#T_00b8e_row7_col21,#T_00b8e_row7_col22,#T_00b8e_row7_col23,#T_00b8e_row8_col0,#T_00b8e_row8_col21,#T_00b8e_row8_col22,#T_00b8e_row8_col23,#T_00b8e_row9_col0,#T_00b8e_row9_col21,#T_00b8e_row9_col22,#T_00b8e_row9_col23{
#             background-color:  #ffffff;
#             color:  #000000;
#         }#T_00b8e_row0_col1,#T_00b8e_row4_col2{
#             background-color:  #fcfcf7;
#             color:  #000000;
#         }#T_00b8e_row0_col2,#T_00b8e_row1_col19,#T_00b8e_row2_col19{
#             background-color:  #fafaf1;
#             color:  #000000;
#         }#T_00b8e_row0_col3,#T_00b8e_row1_col1,#T_00b8e_row6_col1{
#             background-color:  #f5f5e0;
#             color:  #000000;
#         }#T_00b8e_row0_col4,#T_00b8e_row1_col11,#T_00b8e_row3_col10{
#             background-color:  #eeeeca;
#             color:  #000000;
#         }#T_00b8e_row0_col5,#T_00b8e_row0_col6,#T_00b8e_row4_col8{
#             background-color:  #f1f1d4;
#             color:  #000000;
#         }#T_00b8e_row0_col7,#T_00b8e_row4_col18,#T_00b8e_row5_col9,#T_00b8e_row7_col11{
#             background-color:  #ececc2;
#             color:  #000000;
#         }#T_00b8e_row0_col8,#T_00b8e_row6_col14{
#             background-color:  #e7e5b2;
#             color:  #000000;
#         }#T_00b8e_row0_col9,#T_00b8e_row1_col5,#T_00b8e_row2_col12,#T_00b8e_row8_col3{
#             background-color:  #e1d6a9;
#             color:  #000000;
#         }#T_00b8e_row0_col10,#T_00b8e_row1_col13,#T_00b8e_row2_col16{
#             background-color:  #dfd1a7;
#             color:  #000000;
#         }#T_00b8e_row0_col11{
#             background-color:  #d7bd9c;
#             color:  #000000;
#         }#T_00b8e_row0_col12{
#             background-color:  #d0ac94;
#             color:  #000000;
#         }#T_00b8e_row0_col13{
#             background-color:  #af7272;
#             color:  #000000;
#         }#T_00b8e_row0_col14{
#             background-color:  #1e0000;
#             color:  #f1f1f1;
#         }#T_00b8e_row0_col15,#T_00b8e_row1_col14{
#             background-color:  #bd7b7b;
#             color:  #000000;
#         }#T_00b8e_row0_col16{
#             background-color:  #cea590;
#             color:  #000000;
#         }#T_00b8e_row0_col17{
#             background-color:  #c27f7e;
#             color:  #000000;
#         }#T_00b8e_row0_col18{
#             background-color:  #c58a83;
#             color:  #000000;
#         }#T_00b8e_row0_col19,#T_00b8e_row5_col12,#T_00b8e_row7_col16,#T_00b8e_row7_col17,#T_00b8e_row9_col10{
#             background-color:  #e9e9b8;
#             color:  #000000;
#         }#T_00b8e_row0_col20,#T_00b8e_row8_col1{
#             background-color:  #fcfcf6;
#             color:  #000000;
#         }#T_00b8e_row1_col2,#T_00b8e_row5_col18,#T_00b8e_row6_col16{
#             background-color:  #f2f2d5;
#             color:  #000000;
#         }#T_00b8e_row1_col3,#T_00b8e_row8_col17{
#             background-color:  #dac6a1;
#             color:  #000000;
#         }#T_00b8e_row1_col4,#T_00b8e_row6_col5,#T_00b8e_row9_col14{
#             background-color:  #cda18e;
#             color:  #000000;
#         }#T_00b8e_row1_col6,#T_00b8e_row5_col8,#T_00b8e_row5_col16{
#             background-color:  #ededc6;
#             color:  #000000;
#         }#T_00b8e_row1_col7,#T_00b8e_row3_col7,#T_00b8e_row5_col6{
#             background-color:  #f0f0ce;
#             color:  #000000;
#         }#T_00b8e_row1_col8,#T_00b8e_row3_col8,#T_00b8e_row9_col8{
#             background-color:  #eeeec9;
#             color:  #000000;
#         }#T_00b8e_row1_col9,#T_00b8e_row3_col6,#T_00b8e_row3_col11{
#             background-color:  #eeeec7;
#             color:  #000000;
#         }#T_00b8e_row1_col10,#T_00b8e_row9_col3{
#             background-color:  #efefcc;
#             color:  #000000;
#         }#T_00b8e_row1_col12,#T_00b8e_row6_col10,#T_00b8e_row9_col9{
#             background-color:  #ebebbe;
#             color:  #000000;
#         }#T_00b8e_row1_col15{
#             background-color:  #e1d7aa;
#             color:  #000000;
#         }#T_00b8e_row1_col16,#T_00b8e_row5_col17{
#             background-color:  #ededc5;
#             color:  #000000;
#         }#T_00b8e_row1_col17,#T_00b8e_row2_col9,#T_00b8e_row3_col15,#T_00b8e_row5_col7{
#             background-color:  #f0f0cf;
#             color:  #000000;
#         }#T_00b8e_row1_col18,#T_00b8e_row3_col18,#T_00b8e_row8_col2{
#             background-color:  #f3f3db;
#             color:  #000000;
#         }#T_00b8e_row1_col20,#T_00b8e_row2_col20,#T_00b8e_row5_col20{
#             background-color:  #fffffe;
#             color:  #000000;
#         }#T_00b8e_row2_col1,#T_00b8e_row3_col0,#T_00b8e_row4_col1{
#             background-color:  #fefefc;
#             color:  #000000;
#         }#T_00b8e_row2_col2{
#             background-color:  #fdfdfa;
#             color:  #000000;
#         }#T_00b8e_row2_col3,#T_00b8e_row7_col3{
#             background-color:  #fbfbf4;
#             color:  #000000;
#         }#T_00b8e_row2_col4,#T_00b8e_row2_col5,#T_00b8e_row5_col19,#T_00b8e_row6_col19{
#             background-color:  #fafaef;
#             color:  #000000;
#         }#T_00b8e_row2_col6,#T_00b8e_row4_col19,#T_00b8e_row7_col6{
#             background-color:  #f9f9ed;
#             color:  #000000;
#         }#T_00b8e_row2_col7,#T_00b8e_row5_col1{
#             background-color:  #f6f6e4;
#             color:  #000000;
#         }#T_00b8e_row2_col8,#T_00b8e_row4_col7,#T_00b8e_row6_col18{
#             background-color:  #f4f4dc;
#             color:  #000000;
#         }#T_00b8e_row2_col10,#T_00b8e_row6_col11{
#             background-color:  #ececc1;
#             color:  #000000;
#         }#T_00b8e_row2_col11{
#             background-color:  #e6e4b1;
#             color:  #000000;
#         }#T_00b8e_row2_col13{
#             background-color:  #cb9c8c;
#             color:  #000000;
#         }#T_00b8e_row2_col14{
#             background-color:  #7b4e4e;
#             color:  #f1f1f1;
#         }#T_00b8e_row2_col15{
#             background-color:  #d1ae95;
#             color:  #000000;
#         }#T_00b8e_row2_col17,#T_00b8e_row8_col10{
#             background-color:  #e4ddad;
#             color:  #000000;
#         }#T_00b8e_row2_col18,#T_00b8e_row3_col9,#T_00b8e_row4_col10,#T_00b8e_row5_col10{
#             background-color:  #ededc4;
#             color:  #000000;
#         }#T_00b8e_row3_col1{
#             background-color:  #f8f8e9;
#             color:  #000000;
#         }#T_00b8e_row3_col2{
#             background-color:  #f4f4dd;
#             color:  #000000;
#         }#T_00b8e_row3_col3{
#             background-color:  #decfa6;
#             color:  #000000;
#         }#T_00b8e_row3_col4{
#             background-color:  #cea48f;
#             color:  #000000;
#         }#T_00b8e_row3_col5{
#             background-color:  #e0d4a8;
#             color:  #000000;
#         }#T_00b8e_row3_col12,#T_00b8e_row5_col11,#T_00b8e_row6_col2{
#             background-color:  #ececc0;
#             color:  #000000;
#         }#T_00b8e_row3_col13,#T_00b8e_row6_col9{
#             background-color:  #e9e9b6;
#             color:  #000000;
#         }#T_00b8e_row3_col14{
#             background-color:  #e6e3b1;
#             color:  #000000;
#         }#T_00b8e_row3_col16,#T_00b8e_row5_col2{
#             background-color:  #f2f2d7;
#             color:  #000000;
#         }#T_00b8e_row3_col17,#T_00b8e_row6_col17{
#             background-color:  #f2f2d6;
#             color:  #000000;
#         }#T_00b8e_row3_col19,#T_00b8e_row4_col3,#T_00b8e_row7_col19{
#             background-color:  #fafaf0;
#             color:  #000000;
#         }#T_00b8e_row3_col20,#T_00b8e_row4_col20,#

# %%
#행 기준 히트맵
top10_mean_hour.style.background_gradient(cmap='pink_r', axis=1).format('{:.0f}')
# Out:
# <style  type="text/css" >
# #T_705a1_row0_col0,#T_705a1_row0_col21,#T_705a1_row0_col22,#T_705a1_row0_col23,#T_705a1_row1_col0,#T_705a1_row1_col21,#T_705a1_row1_col22,#T_705a1_row1_col23,#T_705a1_row2_col0,#T_705a1_row2_col21,#T_705a1_row2_col22,#T_705a1_row2_col23,#T_705a1_row3_col21,#T_705a1_row3_col22,#T_705a1_row3_col23,#T_705a1_row4_col0,#T_705a1_row4_col21,#T_705a1_row4_col22,#T_705a1_row4_col23,#T_705a1_row5_col21,#T_705a1_row5_col22,#T_705a1_row5_col23,#T_705a1_row6_col0,#T_705a1_row6_col21,#T_705a1_row6_col22,#T_705a1_row6_col23,#T_705a1_row7_col0,#T_705a1_row7_col21,#T_705a1_row7_col22,#T_705a1_row7_col23,#T_705a1_row8_col0,#T_705a1_row8_col21,#T_705a1_row8_col22,#T_705a1_row8_col23,#T_705a1_row9_col21,#T_705a1_row9_col22,#T_705a1_row9_col23{
#             background-color:  #ffffff;
#             color:  #000000;
#         }#T_705a1_row0_col1,#T_705a1_row7_col2{
#             background-color:  #fcfcf7;
#             color:  #000000;
#         }#T_705a1_row0_col2{
#             background-color:  #fafaf1;
#             color:  #000000;
#         }#T_705a1_row0_col3,#T_705a1_row4_col4{
#             background-color:  #f5f5e0;
#             color:  #000000;
#         }#T_705a1_row0_col4,#T_705a1_row4_col8{
#             background-color:  #eeeeca;
#             color:  #000000;
#         }#T_705a1_row0_col5,#T_705a1_row0_col6,#T_705a1_row3_col1{
#             background-color:  #f1f1d4;
#             color:  #000000;
#         }#T_705a1_row0_col7,#T_705a1_row7_col18{
#             background-color:  #ececc2;
#             color:  #000000;
#         }#T_705a1_row0_col8,#T_705a1_row6_col7{
#             background-color:  #e7e5b2;
#             color:  #000000;
#         }#T_705a1_row0_col9,#T_705a1_row3_col7,#T_705a1_row9_col3{
#             background-color:  #e1d6a9;
#             color:  #000000;
#         }#T_705a1_row0_col10,#T_705a1_row2_col17,#T_705a1_row3_col10,#T_705a1_row5_col2{
#             background-color:  #dfd1a7;
#             color:  #000000;
#         }#T_705a1_row0_col11,#T_705a1_row5_col6,#T_705a1_row9_col4{
#             background-color:  #d7bd9c;
#             color:  #000000;
#         }#T_705a1_row0_col12,#T_705a1_row5_col17,#T_705a1_row8_col3{
#             background-color:  #d0ac94;
#             color:  #000000;
#         }#T_705a1_row0_col13{
#             background-color:  #af7272;
#             color:  #000000;
#         }#T_705a1_row0_col14,#T_705a1_row1_col14,#T_705a1_row2_col14,#T_705a1_row3_col4,#T_705a1_row4_col14,#T_705a1_row5_col4,#T_705a1_row6_col4,#T_705a1_row7_col14,#T_705a1_row8_col14,#T_705a1_row9_col14{
#             background-color:  #1e0000;
#             color:  #f1f1f1;
#         }#T_705a1_row0_col15{
#             background-color:  #bd7b7b;
#             color:  #000000;
#         }#T_705a1_row0_col16,#T_705a1_row8_col5,#T_705a1_row8_col11{
#             background-color:  #cea590;
#             color:  #000000;
#         }#T_705a1_row0_col17{
#             background-color:  #c27f7e;
#             color:  #000000;
#         }#T_705a1_row0_col18{
#             background-color:  #c58a83;
#             color:  #000000;
#         }#T_705a1_row0_col19,#T_705a1_row2_col18,#T_705a1_row6_col11{
#             background-color:  #e9e9b8;
#             color:  #000000;
#         }#T_705a1_row0_col20{
#             background-color:  #fcfcf6;
#             color:  #000000;
#         }#T_705a1_row1_col1,#T_705a1_row7_col9{
#             background-color:  #f0f0ce;
#             color:  #000000;
#         }#T_705a1_row1_col2,#T_705a1_row3_col2{
#             background-color:  #eaeaba;
#             color:  #000000;
#         }#T_705a1_row1_col3{
#             background-color:  #c48581;
#             color:  #000000;
#         }#T_705a1_row1_col4{
#             background-color:  #8a5858;
#             color:  #f1f1f1;
#         }#T_705a1_row1_col5,#T_705a1_row1_col15,#T_705a1_row7_col15{
#             background-color:  #cea691;
#             color:  #000000;
#         }#T_705a1_row1_col6,#T_705a1_row1_col9,#T_705a1_row6_col14,#T_705a1_row7_col17,#T_705a1_row9_col7{
#             background-color:  #e4ddad;
#             color:  #000000;
#         }#T_705a1_row1_col7{
#             background-color:  #e6e4b1;
#             color:  #000000;
#         }#T_705a1_row1_col8{
#             background-color:  #e4dfae;
#             color:  #000000;
#         }#T_705a1_row1_col10,#T_705a1_row3_col16,#T_705a1_row6_col9{
#             background-color:  #e6e3b1;
#             color:  #000000;
#         }#T_705a1_row1_col11,#T_705a1_row6_col13{
#             background-color:  #e5e0af;
#             color:  #000000;
#         }#T_705a1_row1_col12{
#             background-color:  #e0d4a8;
#             color:  #000000;
#         }#T_705a1_row1_col13,#T_705a1_row9_col11{
#             background-color:  #cb9c8c;
#             color:  #000000;
#         }#T_705a1_row1_col16{
#             background-color:  #e3dbac;
#             color:  #000000;
#         }#T_705a1_row1_col17,#T_705a1_row6_col12,#T_705a1_row7_col11,#T_705a1_row9_col6{
#             background-color:  #e7e6b2;
#             color:  #000000;
#         }#T_705a1_row1_col18,#T_705a1_row2_col9,#T_705a1_row7_col10{
#             background-color:  #ededc5;
#             color:  #000000;
#         }#T_705a1_row1_col19,#T_705a1_row4_col19,#T_705a1_row7_col5,#T_705a1_row7_col6{
#             background-color:  #f8f8e8;
#             color:  #000000;
#         }#T_705a1_row1_col20,#T_705a1_row2_col20,#T_705a1_row4_col20,#T_705a1_row6_col20,#T_705a1_row7_col20{
#             background-color:  #fefefd;
#             color:  #000000;
#         }#T_705a1_row2_col1,#T_705a1_row4_col1{
#             background-color:  #fefefb;
#             color:  #000000;
#         }#T_705a1_row2_col2,#T_705a1_row5_col0{
#             background-color:  #fdfdf9;
#             color:  #000000;
#         }#T_705a1_row2_col3,#T_705a1_row7_col3,#T_705a1_row8_col1,#T_705a1_row9_col20{
#             background-color:  #fbfbf2;
#             color:  #000000;
#         }#T_705a1_row2_col4,#T_705a1_row2_col5,#T_705a1_row4_col3,#T_705a1_row6_col19,#T_705a1_row7_col19{
#             background-color:  #f9f9eb;
#             color:  #000000;
#         }#T_705a1_row2_col6{
#             background-color:  #f8f8ea;
#             color:  #000000;
#         }#T_705a1_row2_col7,#T_705a1_row3_col19,#T_705a1_row7_col7{
#             background-color:  #f5f5df;
#             color:  #000000;
#         }#T_705a1_row2_col8,#T_705a1_row5_col19{
#             background-color:  #f2f2d5;
#             color:  #000000;
#         }#T_705a1_row2_col10,#T_705a1_row5_col1,#T_705a1_row6_col10{
#             background-color:  #e9e9b5;
#             color:  #000000;
#         }#T_705a1_row2_col11,#T_705a1_row4_col11,#T_705a1_row4_col16,#T_705a1_row9_col5{
#             background-color:  #e2daac;
#             color:  #000000;
#         }#T_705a1_row2_col12{
#             background-color:  #dbc8a2;
#             color:  #000000;
#         }#T_705a1_row2_col13,#T_705a1_row5_col5{
#             background-color:  #c17d7d;
#             color:  #000000;
#         }#T_705a1_row2_col15{
#             background-color:  #c99588;
#             color:  #000000;
#         }#T_705a1_row2_col16,#T_705a1_row3_col12{
#             background-color:  #d9c29f;
#             color:  #000000;
#         }#T_705a1_row2_col19{
#             background-color:  #fafaef;
#             color:  #000000;
#         }#T_705a1_row3_col0{
#             background-color:  #fdfdfa;
#             color:  #000000;
#         }#T_705a1_row3_col3{
#             background-color:  #b17272;
#             color:  #000000;
#         }#T_705a1_row3_col5{
#             background-color:  #ba7979;
#             color:  #000000;
#         }#T_705a1_row3_col6,#T_705a1_row3_col11{
#             background-color:  #ddcca4;
#             color:  #000000;
#         }#T_705a1_row3_col8{
#             background-color:  #ddcea5;
#             color:  #000000;
#         }#T_705a1_row3_col9{
#             background-color:  #dbc7a2;
#             color:  #000000;
#         }#T_705a1_row3_col13,#T_705a1_row9_col19{
#             background-color:  #d3b497;
#             color:  #000000;
#         }#T_705a1_row3_col14{
#             background-color:  #cda28f;
#             color:  #000000;
#         }#T_7

# %% [markdown]
# ### [4] 지하철역 시간대별 인원 유형 군집화

# %% [markdown]
# - 승차 인원으로 유형 군집화

# %%
hour_mean = data.groupby('지하철역')[on_col].mean()
hour_mean.columns = [i[:3] for i in hour_mean.columns]
hour_mean_pct = hour_mean.div(hour_mean.sum(axis=1), axis=0)

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,10))
visualizer.fit(hour_mean_pct)
# Out:
# KElbowVisualizer(ax=<AxesSubplot:>, estimator=KMeans(n_clusters=9), k=(1, 10))

# %%
k = 3
model = KMeans(n_clusters = k, random_state = 10) #KMeans 모델을 정의
model.fit(hour_mean_pct) #학습
hour_mean_pct['cluster'] = model.fit_predict(hour_mean_pct).astype(str) #클러스터 열 만들기

# %%
fig = px.scatter(data_frame = hour_mean_pct[['08시','18시','cluster']].reset_index(), x='08시', y='18시', color='cluster', width=700, height=600, title='시간대별 승차 인원 비중 군집화', hover_name='지하철역')
fig.show()

# %%
for i in range(k):
    print(f'cluster {i}')
    print(list(hour_mean_pct.query(f'cluster == "{i}"').index))
# Out:
# cluster 0
# ['건대입구', '구로디지털단지', '당산', '도림천', '문래', '방배', '사당', '신당', '신도림', '신설동', '신촌', '영등포구청', '왕십리', '이대', '잠실', '종합운동장', '충정로', '합정', '홍대입구']
# cluster 1
# ['강남', '교대', '동대문역사문화공원', '뚝섬', '삼성', '서초', '선릉', '성수', '시청', '역삼', '을지로3가', '을지로4가', '을지로입구', '한양대']
# cluster 2
# ['강변', '구의', '낙성대', '대림', '봉천', '상왕십리', '서울대입구', '신답', '신대방', '신림', '신정네거리', '아현', '양천구청', '용답', '용두', '잠실나루', '잠실새내']

# %% [markdown]
# ### [5] 지도에 분석 결과를 시각화

# %% [markdown]
# -  8시 승차 인원과 18시 승차 인원을 지도에 시각화 해보자

# %% [markdown]
# - 지하철역별 위도 경도 데이터 전처리

# %%
coordinate = pd.read_csv('Data\서울시 역사마스터 정보.csv')
coordinate.head()
# Out:
#    역사_ID   역사명      호선         위도          경도
# 0   9996    미사     5호선  37.560927  127.193877
# 1   9995    강일     5호선  37.557490  127.175930
# 2   4929  김포공항  김포골드라인  37.562360  126.801868
# 3   4928    고촌  김포골드라인  37.601243  126.770345
# 4   4927    풍무  김포골드라인  37.612488  126.732387

# %%
coordinate = coordinate.query('호선 == "2호선"')
coordinate['역사명'] = [i[0] for i in coordinate['역사명'].str.split('(')]
coordinate.rename({'역사명':'지하철역'}, axis=1, inplace=True)
coordinate
# Out:
#      역사_ID       지하철역   호선         위도          경도
# 708    250         용두  2호선  37.574028  127.038091
# 709    249      신정네거리  2호선  37.520074  126.852912
# 710    248       양천구청  2호선  37.512398  126.865819
# 711    247        도림천  2호선  37.514287  126.882768
# 712    246        신설동  2호선  37.574747  127.024932
# 713    245         신답  2호선  37.570040  127.046481
# 714    244         용답  2호선  37.561904  127.050899
# 715    243        충정로  2호선  37.559704  126.964378
# 716    242         아현  2호선  37.557345  126.956141
# 717    241         이대  2호선  37.556733  126.946013
# 718    240         신촌  2호선  37.555131  126.936926
# 719    239       홍대입구  2호선  37.556790  126.923708
# 720    238         합정  2호선  37.549457  126.913808
# 721    237         당산  2호선  37.534946  126.902767
# 722    236      영등포구청  2호선  37.525706  126.896610
# 723    235         문래  2호선  37.517933  126.894760
# 724    234        신도림  2호선  37.508961  126.891084
# 725    233         대림  2호선  37.493243  126.894932
# 726    232    구로디지털단지  2호선  37.485266  126.901401
# 727    231        신대방  2호선  37.487462  126.913149
# 728    230         신림  2호선  37.484201  126.929715
# 729    229         봉천  2호선  37.482362  126.941892
# 730    228      서울대입구  2호선  37.481247  126.952739
# 731    227        낙성대  2호선  37.476930  126.963693
# 732    226         사당  2호선  37.476538  126.981544
# 733    225         방배  2호선  37.481426  126.997596
# 734    224         서초  2호선  37.491897  127.007917
# 735    223         교대  2호선  37.493961  127.014667
# 736    222         강남  2호선  37.497990  127.027912
# 737    221         역삼  2호선  37.500622  127.036456
# 738    220         선릉  2호선  37.504286  127.048203
# 739    219         삼성  2호선  37.508844  127.063160
# 740    218      종합운동장  2호선  37.511022  127.073704
# 741    217       잠실새내  2호선  37.511687  127.086162
# 742    216         잠실  2호선  37.513262  127.100159
# 743    215       잠실나루  2호선  37.520733  127.103790
# 744    214         강변  2호선  37.535095  127.094681
# 745    213         구의  2호선  37.537077  127.085916
# 746    212       건대입구  2호선  37.540373  127.069191
# 747    211         성수  2호선  37.544581  127.055961
# 748    210         뚝섬  2호선  37.547184  127.047367
# 749    209        한양대  2호선  37.555273  127.043655
# 750    208        왕십리  2호선  37.561238  127.036954
# 751    207       상왕십리  2호선  37.564354  127.029354
# 752    206         신당  2호선  37.565640  127.019614
# 753    205  동대문역사문화공원  2호선  37.565613  127.009054
# 754    204      을지로4가  2호선  37.566595  126.997817
# 755    203      을지로3가  2호선  37.566306  126.991696
# 756    202      을지로입구  2호선  37.566014  126.982618
# 757    201         시청  2호선  37.563588  126.975411

# %%
hour_mean_merge = hour_mean.reset_index()[['지하철역','08시','18시']]
coordinate_merge = coordinate[['지하철역','위도','경도']]
hour_mean_coor = pd.merge(hour_mean_merge, coordinate_merge, on='지하철역')

# %%
hour_mean_coor['cluster'] = model.fit_predict(hour_mean_pct).astype(str)
hour_mean_coor.head()
# Out:
#       지하철역            08시            18시         위도          경도 cluster
# 0       강남   64827.731343  343752.835821  37.497990  127.027912       2
# 1       강변  119168.985075   71631.000000  37.535095  127.094681       1
# 2     건대입구   94501.731343   89339.671642  37.540373  127.069191       0
# 3       교대   37022.164179  144218.925373  37.493961  127.014667       2
# 4  구로디지털단지  182999.328358  223309.611940  37.485266  126.901401       0

# %% [markdown]
# - 지도에 시각화

# %%
import folium
from folium import plugins

# %%
center = [37.541, 126.986] #서울 중간

m = folium.Map(location=center, zoom_start=12)
m.add_child(plugins.HeatMap(zip(hour_mean_coor['위도'], hour_mean_coor['경도'], hour_mean_coor['08시'])))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f53976c5b18e7f2e5bd033ef796e124 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f53976c5b18e7f2e5bd033ef796e124&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f53976c5b18e7f2e5bd033ef796e124 = L.map(
#                 &quot;map_8f53976c5b18e7f2e5bd033ef796e124&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbb24c6f874611cec84ca5802b91e827 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_dbb24c6f874611cec84ca5802b91e827.addTo(map_8f53976c5b18e7f2e5bd033ef796e124);
#
#
#             var heat_map_e0220f522aa5f635438cd643d3317470 = L.heatLayer(
#                 [[37.49799, 127.027912, 64827.73134328358], [37.535095, 127.094681, 119168.98507462686], [37.540373, 127.069191, 94501.73134328358], [37.493961, 127.014667, 37022.164179104475], [37.485266, 126.901401, 182999.32835820896], [37.537077, 127.085916, 112258.82089552238], [37.47693, 126.963693, 125625.07462686567], [37.534946, 126.902767, 58876.07462686567], [37.493243, 126.894932, 95339.77611940299], [37.514287, 126.882768, 3241.2985074626868], [37.565613, 127.009054, 11720.059701492537], [37.547184, 127.047367, 28300.492537313432], [37.517933, 126.89476, 45868.253731343284], [37.481426, 126.997596, 33725.850746268654], [37.482362, 126.941892, 116951.28358208956], [37.476538, 126.981544, 98665.67164179105], [37.508844, 127.06316, 21927.223880597016], [37.564354, 127.029354, 60709.07462686567], [37.481247, 126.952739, 180685.80597014926], [37.491897, 127.007917, 24362.402985074626], [37.504286, 127.048203, 32790.985074626864], [37.544581, 127.055961, 31636.910447761195], [37.563588, 126.975411, 7772.268656716418], [37.57004, 127.046481, 9927.208955223881], [37.56564, 127.019614, 43319.164179104475], [37.487462, 126.913149, 129882.80597014926], [37.508961, 126.891084, 140965.08955223882], [37.484201, 126.929715, 305087.70149253734], [37.574747, 127.024932, 6333.059701492537], [37.520074, 126.852912, 41825.59701492537], [37.555131, 126.936926, 51014.40298507463], [37.557345, 126.956141, 36793.17910447761], [37.512398, 126.865819, 29011.97014925373], [37.500622, 127.036456, 25531.537313432837], [37.525706, 126.89661, 46565.41791044776], [37.561238, 127.036954, 46934.388059701494], [37.561904, 127.050899, 12721.910447761195], [37.574028, 127.038091, 8007.223880597015], [37.566306, 126.991696, 10073.119402985074], [37.566595, 126.997817, 6652.104477611941], [37.566014, 126.982618, 14691.388059701492], [37.556733, 126.946013, 28275.432835820895], [37.513262, 127.100159, 166209.07462686568], [37.520733, 127.10379, 48892.65671641791], [37.511687, 127.086162, 76721.44776119402], [37.511022, 127.073704, 24669.83582089552], [37.559704, 126.964378, 22509.5223880597], [37.555273, 127.043655, 8587.179104477613], [37.549457, 126.913808, 55157.477611940296], [37.55679, 126.923708, 80009.19402985074]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             );
#
#
#             heat_map_e0220f522aa5f635438cd643d3317470.addTo(map_8f53976c5b18e7f2e5bd033ef796e124);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=center, zoom_start=12)
m.add_child(plugins.HeatMap(zip(hour_mean_coor['위도'], hour_mean_coor['경도'], hour_mean_coor['18시'])))
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_202f5495aa1d3a8ceebab3541f3fc47c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_202f5495aa1d3a8ceebab3541f3fc47c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_202f5495aa1d3a8ceebab3541f3fc47c = L.map(
#                 &quot;map_202f5495aa1d3a8ceebab3541f3fc47c&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c1361ed9f6ad0738a4dc166e4fa680c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8c1361ed9f6ad0738a4dc166e4fa680c.addTo(map_202f5495aa1d3a8ceebab3541f3fc47c);
#
#
#             var heat_map_2a29fca7bd3cf6b8b538c535ab7d6896 = L.heatLayer(
#                 [[37.49799, 127.027912, 343752.8358208955], [37.535095, 127.094681, 71631.0], [37.540373, 127.069191, 89339.67164179105], [37.493961, 127.014667, 144218.92537313432], [37.485266, 126.901401, 223309.61194029852], [37.537077, 127.085916, 43149.91044776119], [37.47693, 126.963693, 52412.388059701494], [37.534946, 126.902767, 62581.80597014925], [37.493243, 126.894932, 57793.55223880597], [37.514287, 126.882768, 3535.955223880597], [37.565613, 127.009054, 49874.522388059704], [37.547184, 127.047367, 110982.68656716419], [37.517933, 126.89476, 97522.05970149254], [37.481426, 126.997596, 69528.32835820895], [37.482362, 126.941892, 34279.94029850746], [37.476538, 126.981544, 93211.4776119403], [37.508844, 127.06316, 294941.1194029851], [37.564354, 127.029354, 28682.13432835821], [37.481247, 126.952739, 95358.58208955223], [37.491897, 127.007917, 102142.37313432836], [37.504286, 127.048203, 283547.05970149254], [37.544581, 127.055961, 204126.55223880598], [37.563588, 126.975411, 166153.25373134328], [37.57004, 127.046481, 2161.179104477612], [37.56564, 127.019614, 34864.92537313433], [37.487462, 126.913149, 41553.58208955224], [37.508961, 126.891084, 134345.71641791044], [37.484201, 126.929715, 93013.23880597015], [37.574747, 127.024932, 14115.223880597016], [37.520074, 126.852912, 12273.029850746268], [37.555131, 126.936926, 101968.26865671642], [37.557345, 126.956141, 20149.597014925374], [37.512398, 126.865819, 9142.44776119403], [37.500622, 127.036456, 274455.74626865675], [37.525706, 126.89661, 100806.20895522388], [37.561238, 127.036954, 40442.80597014925], [37.561904, 127.050899, 3907.805970149254], [37.574028, 127.038091, 5842.7164179104475], [37.566306, 126.991696, 128891.14925373135], [37.566595, 126.997817, 66152.01492537314], [37.566014, 126.982618, 261096.83582089553], [37.556733, 126.946013, 42152.388059701494], [37.513262, 127.100159, 231972.44776119402], [37.520733, 127.10379, 31999.611940298506], [37.511687, 127.086162, 42942.119402985074], [37.511022, 127.073704, 22144.16417910448], [37.559704, 126.964378, 49897.86567164179], [37.555273, 127.043655, 32705.149253731342], [37.549457, 126.913808, 110607.85074626865], [37.55679, 126.923708, 183824.5223880597]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             );
#
#
#             heat_map_2a29fca7bd3cf6b8b538c535ab7d6896.addTo(map_202f5495aa1d3a8ceebab3541f3fc47c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - 승차 인원 유형을 지도에 시각화

# %%
m = folium.Map(location=center, zoom_start=12)

for idx in hour_mean_coor.index:
    lat = hour_mean_coor.loc[idx, '위도']
    long = hour_mean_coor.loc[idx, '경도']
    title = hour_mean_coor.loc[idx, '지하철역']

    if hour_mean_coor.loc[idx, 'cluster'] == "0":
        color = '#000000'
    elif hour_mean_coor.loc[idx, 'cluster'] == "1":
        color = '#3A01DF'
    else:
        color = '#DF0101'

    folium.CircleMarker([lat, long]
                        , radius=18
                        , color = color
                        , fill = color
                        , tooltip = title).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cbfd430e248472fb2b5f8fba6b4913cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cbfd430e248472fb2b5f8fba6b4913cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cbfd430e248472fb2b5f8fba6b4913cf = L.map(
#                 &quot;map_cbfd430e248472fb2b5f8fba6b4913cf&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c8596a5fb889e6a8aa54b7df529d7f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9c8596a5fb889e6a8aa54b7df529d7f3.addTo(map_cbfd430e248472fb2b5f8fba6b4913cf);
#
#
#             var circle_marker_1a6d7fbbf0da8455d2c5458a13c5c4a1 = L.circleMarker(
#                 [37.49799, 127.027912],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#DF0101&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: &quot;#DF0101&quot;, &quot;fillColor&quot;: &quot;#DF0101&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 18, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cbfd430e248472fb2b5f8fba6b4913cf);
#
#
#             circle_marker_1a6d7fbbf0da8455d2c5458a13c5c4a1.bindTooltip(
#                 `&lt;div&gt;
#                      강남
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_7621f59fd31dd7b5a7602e63ab1faec0 = L.circleMarker(
#                 [37.535095, 127.094681],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3A01DF&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: &quot;#3A01DF&quot;, &quot;fillColor&quot;: &quot;#3A01DF&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 18, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cbfd430e248472fb2b5f8fba6b4913cf);
#
#
#             circle_marker_7621f59fd31dd7b5a7602e63ab1faec0.bindTooltip(
#                 `&lt;div&gt;
#                      강변
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_df49153ad3d12c1529cff193f20f63e1 = L.circleMarker(
#                 [37.540373, 127.069191],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: &quot;#000000&quot;, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 18, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cbfd430e248472fb2b5f8fba6b4913cf);
#
#
#             circle_marker_df49153ad3d12c1529cff193f20f63e1.bindTooltip(
#                 `&lt;div&gt;
#                      건대입구
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_3fae9d62eec0c0d60364401579245545 = L.circleMarker(
#                 [37.493961, 127.014667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#DF0101&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: &quot;#DF0101&quot;, &quot;fillColor&quot;: &quot;#DF0101&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 18, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cbfd430e248472fb2b5f8fba6b4913cf);
#
#
#             circle_marker_3fae9d62eec0c0d60364401579245545.bindTooltip(
#                 `&lt;div&gt;
#                      교대
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_f2337ed72032de37abfbd0759037b853 = L.circleMarker(
#                 [37.485266, 126.901401],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: &quot;#000000&quot;, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &

# %% [markdown]
# ## **정리**

# %% [markdown]
# [1] 승하차 인원이 가장 많은 역은?
# - 강남, 잠실, 홍대입구, 신림, 구로디지털단지...
#
# [2] 연도별로 혹은 월별로 승차 인원 추이에 차이가 있는가?
# - 코로나가 시작된 2020년, 2021년에 인원이 많이 줄었고 2022년도부터 다시 회복 중
#
# [3] 시간대별로 가장 승차인원이 많은 역은?
# - 아침에 비교적 승차 인원이 많은 역과 저녁에 비교적 승차 인원이 많은 역이 있음을 히트맵으로 파악
#
# [4] 지하철역 시간대별 인원 유형 군집화
#
#     cluster 0: 아침과 저녁 승차인원 비율이 비교적 비슷
#     ['건대입구', '구로디지털단지', '당산', '도림천', '문래', '방배', '사당', '신당', '신도림', '신설동', '신촌', '영등포구청', '왕십리', '이대', '잠실', '종합운동장', '충정로', '합정', '홍대입구']
#     cluster 1: 저녁 승차인원 비율이 높음
#     ['강남', '교대', '동대문역사문화공원', '뚝섬', '삼성', '서초', '선릉', '성수', '시청', '역삼', '을지로3가', '을지로4가', '을지로입구', '한양대']
#     cluster 2: 아침 승차인원 비율이 높음
#     ['강변', '구의', '낙성대', '대림', '봉천', '상왕십리', '서울대입구', '신답', '신대방', '신림', '신정네거리', '아현', '양천구청', '용답', '용두', '잠실나루', '잠실새내']
#
# [5] 지도에 분석 결과를 시각화
# - cluster 0: 주거와 상업 시설, 회사가 비슷하게 분포한 지역
# - cluster 1: 회사가 많이 분포한 지역
# - cluster 2: 주거 지역이 많이 분포한 지역
